# %% [markdown]
# ## Project Group 4 - Rishabh Arora, Nivedya Ashokan, Madhura Pande

# %%
#import pandas library for reading data and merging
import pandas as pd

# %%
#read demographic data
dem_data = pd.read_csv('Demograhic_Data.csv')

# %%
dem_data.head()
# Out:
#    2018rank         City    State[c]  2018estimate
# 0         1     New York    New York       8398748
# 1         2  Los Angeles  California       3990456
# 2         3      Chicago    Illinois       2705994
# 3         4      Houston       Texas       2325502
# 4         5      Phoenix     Arizona       1660272

# %%
#read restaurants data
restaurant_data = pd.read_csv('Restaurants.csv')

# %%
restaurant_data.head()
# Out:
#                        id                                      alias  \
# 0  H4jJ7XB3CetIr1pg56CczQ                     levain-bakery-new-york
# 1  V7lXZKBDzScDeGB8JmnzSA                katzs-delicatessen-new-york
# 2  xEnNFXtMLDF5kZDxfaCJgA                  the-halal-guys-new-york-2
# 3  44SY464xDHbvOcjDzRbKkQ                       ippudo-ny-new-york-7
# 4  jVncyqXwlx_D9f2xZn05tg  the-metropolitan-museum-of-art-new-york-3
#
#                              name  \
# 0                   Levain Bakery
# 1             Katz's Delicatessen
# 2                  The Halal Guys
# 3                       Ippudo NY
# 4  The Metropolitan Museum of Art
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/zgjSt_...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/B6xNx7...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/24lb-V...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/zF3Egq...      False
# ...

# %%
#merge data using left join
combined_data = restaurant_data.merge(dem_data, left_on='city', right_on='City', how='left', copy=False)

# %%
combined_data.head()
# Out:
#                        id                                      alias  \
# 0  H4jJ7XB3CetIr1pg56CczQ                     levain-bakery-new-york
# 1  V7lXZKBDzScDeGB8JmnzSA                katzs-delicatessen-new-york
# 2  xEnNFXtMLDF5kZDxfaCJgA                  the-halal-guys-new-york-2
# 3  44SY464xDHbvOcjDzRbKkQ                       ippudo-ny-new-york-7
# 4  jVncyqXwlx_D9f2xZn05tg  the-metropolitan-museum-of-art-new-york-3
#
#                              name  \
# 0                   Levain Bakery
# 1             Katz's Delicatessen
# 2                  The Halal Guys
# 3                       Ippudo NY
# 4  The Metropolitan Museum of Art
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/zgjSt_...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/B6xNx7...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/24lb-V...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/zF3Egq...      False
# ...

# %%
#write final data file to csv
combined_data.to_csv('Final_Data.csv', index=False)
